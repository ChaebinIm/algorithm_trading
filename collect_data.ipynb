# %%
import ccxt
import pandas as pd
import time
from pathlib import Path

# %% [markdown]
# ### 이건 간단하게 CCXT를 이용해서 데이터(1분봉)를 가져오는 코드 예시.

# %%
EXCHANGE = ccxt.upbit({"enableRateLimit" : True})
SYMBOL = "BTC/KRW" # 업비트 심볼 표기 방법. 비트코인(BTC/KRW), 이더리움(ETH/KRW), 리플(XRP/KRW), 솔라나(SOL/KRW), 바이낸스코인(BNB/KRW)로 바꾸면댐.
TIMEFRAME = "1m" # 1분단위로 가져올 것.
LIMIT = 200 # 업비트 OHLCV 호출 최대치 근처

# %%
EXCHANGE.load_markets()
ohlcv = EXCHANGE.fetch_ohlcv(SYMBOL, timeframe = TIMEFRAME, limit = LIMIT)
# CCXT 표준 컬럼이 [timestamp, open, high, low, close, volume]임.
df = pd.DataFrame(ohlcv, columns = ["ts", "open", "high", "low", "close", "volume"])
df["time"] = pd.to_datetime(df["ts"], unit = "ms", utc = True).dt.tz_convert("Asia/Seoul") # UTC 기준 타임스탬프 -> 한국 표준 시간으로 변경

# %%
df
# Out:
#                 ts         open         high          low        close  \
# 0    1762986480000  153547000.0  153600000.0  153536000.0  153600000.0
# 1    1762986540000  153600000.0  153600000.0  153536000.0  153600000.0
# 2    1762986600000  153600000.0  153600000.0  153583000.0  153599000.0
# 3    1762986660000  153597000.0  153599000.0  153583000.0  153583000.0
# 4    1762986720000  153599000.0  153600000.0  153541000.0  153541000.0
# ..             ...          ...          ...          ...          ...
# 195  1762998180000  154369000.0  154370000.0  154353000.0  154360000.0
# 196  1762998240000  154360000.0  154370000.0  154357000.0  154370000.0
# 197  1762998300000  154370000.0  154421000.0  154370000.0  154420000.0
# 198  1762998360000  154420000.0  154450000.0  154403000.0  154415000.0
# 199  1762998420000  154419000.0  154419000.0  154374000.0  154397000.0
#
#        volume                      time
# 0    0.363083 2025-11-13 07:28:00+09:00
# 1    0.270751 2025-11-13 07:29:00+09:00
# 2    0.410808 2025-11-13 07:30:00+09:00
# 3    0.370508 2025-11-13 07:31:00+09:00
# 4    0.990989 2025-11-13 07:32:00+09:00
# ..        ...                       ...
# 195  0.162055 2025-11-13 10:43:00+09:00
# 196  0.546068 2025-11-13 10:44:00+09:00
# 197  0.400124 2025-11-13 10:45:00+09:00
# 198  1.080546 2025-11-13 10:46:00+09:00
# 199  0.180389 2025-11-13 10:47:00+09:00
#
# [200 rows x 7 columns]

# %% [markdown]
# ### 이제 데이터를 쌓고 저장해보자. (비트코인)

# %%
SYMBOL = "XRP/KRW"                # 비트코인(BTC/KRW), 이더리움(ETH/KRW), 리플(XRP/KRW), 솔라나(SOL/KRW), 바이낸스코인(BNB/KRW)로 바꾸면댐.
TIMEFRAME = "1h"                  # 1분봉
CHUNK_LIMIT = 200                 # Upbit 한 번에 가져올 최대 근처
SAVE_PATH = "data/ohlcv_full_{}_{}.parquet".format(SYMBOL.replace("/",""), TIMEFRAME)
START_ISO = "2020-01-01T00:00:00Z" # 시작일(원하면 바꾸세요)
END_BUFFER_SEC = 60               # 최신 캔들 확정 여유(초)
MAX_EMPTY_CHUNKS = 10             # 연속 빈 응답 허용 횟수(초과 시 종료)

# %%
# timeframe → 밀리초
TIMEFRAME_MS = {
    "1m": 60_000, "3m": 180_000, "5m": 300_000, "15m": 900_000, "30m": 1_800_000,
    "1h": 3_600_000, "4h": 14_400_000, "1d": 86_400_000,
}[TIMEFRAME]

# %%
# Upbit 객체 생성
ex = ccxt.upbit({"enableRateLimit": True})
ex.load_markets()
# Out:
# {'BERA/BTC': {'id': 'BTC-BERA',
#   'lowercaseId': None,
#   'symbol': 'BERA/BTC',
#   'base': 'BERA',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'BERA',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-BERA',
#    'korean_name': '베라체인',
#    'english_name': 'Berachain'},
#   'tierBased': False,
#   'percentage': True},
#  'FIL/BTC': {'id': 'BTC-FIL',
#   'lowercaseId': None,
#   'symbol': 'FIL/BTC',
#   'base': 'FIL',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'FIL',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-FIL',
#    'korean_name': '파일코인',
#    'english_name': 'Filecoin'},
#   'tierBased': False,
#   'percentage': True},
#  'SIGN/BTC': {'id': 'BTC-SIGN',
#   'lowercaseId': None,
#   'symbol': 'SIGN/BTC',
#   'base': 'SIGN',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'SIGN',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-SIGN', 'korean_name': '사인', 'english_name': 'Sign'},
#   'tierBased': False,
#   'percentage': True},
#  'VIRTUAL/BTC': {'id': 'BTC-VIRTUAL',
#   'lowercaseId': None,
#   'symbol': 'VIRTUAL/BTC',
#   'base': 'VIRTUAL',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'VIRTUAL',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-VIRTUAL',
#    'korean_name': '버추얼프로토콜',
#    'english_name': 'Virtuals Protocol'},
#   'tierBased': False,
#   'percentage': True},
#  'BAT/BTC': {'id': 'BTC-BAT',
#   'lowercaseId': None,
#   'symbol': 'BAT/BTC',
#   'base': 'BAT',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'BAT',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-BAT',
#    'korean_name': '베이직어텐션토큰',
#    'english_name': 'Basic Attention Token'},
#   'tierBased': False,
#   'percentage': True},
#  'WAXP/KRW': {'id': 'KRW-WAXP',
#   'lowercaseId': None,
#   'symbol': 'WAXP/KRW',
#   'base': 'WAXP',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'WAXP',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-WAXP', 'korean_name': '왁스', 'english_name': 'WAX'},
#   'tierBased': False,
#   'percentage': True},
#  'PEPE/USDT': {'id': 'USDT-PEPE',
#   'lowercaseId': None,
#   'symbol': 'PEPE/USDT',
#   'base': 'PEPE',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'PEPE',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-PEPE', 'korean_name': '페페', 'english_name': 'Pepe'},
#   'tierBased': False,
#   'percentage': True},
#  'BAR/BTC': {'id': 'BTC-BAR',
#   'lowercaseId': None,
#   'symbol': 'BAR/BTC',
#   'base': 'BAR',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'BAR',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-BAR',
#    'korean_name': 'FC바르셀로나',
#    'english_name': 'FC Barcelona Fan Token'},
#   'tierBased': False,
#   'percentage': True},
#  'WCT/USDT': {'id': 'USDT-WCT',
#   'lowercaseId': None,
#   'symbol': 'WCT/USDT',
#   'base': 'WCT',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'WCT',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-WCT',
#    'korean_name': '월렛커넥트',
#    'english_name': 'WalletConnect'},
#   'tierBased': False,
#   'percentage': True},
#  'CARV/KRW': {'id': 'KRW-CARV',
#   'lowercaseId': None,
#   'symbol': 'CARV/KRW',
#   'base': 'CARV',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'CARV',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-CARV', 'korean_name': '카브', 'english_name': 'CARV'},
#   'tierBased': False,
#   'percentage': True},
#  'LSK/KRW': {'id': 'KRW-LSK',
#   'lowercaseId': None,
#   'symbol': 'LSK/KRW',
#   'base': 'LSK',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'LSK',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-LSK', 'korean_name': '리스크', 'english_name': 'Lisk'},
#   'tierBased': False,
#   'percentage': True},
#  'DOGE/USDT': {'id': 'USDT-DOGE',
#   'lowercaseId': None,
#   'symbol': 'DOGE/USDT',
#   'base': 'DOGE',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'DOGE',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-DOGE',
#    'korean_name': '도지코인',
#    'english_name': 'Dogecoin'},
#   'tierBased': False,
#   'percentage': True},
#  '0G/KRW': {'id': 'KRW-0G',
#   'lowercaseId': None,
#   'symbol': '0G/KRW',
#   'base': '0G',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': '0G',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-0G', 'korean_name': '제로지', 'english_name': '0G'},
#   'tierBased': False,
#   'percentage': True},
#  'AXL/USDT': {'id': 'USDT-AXL',
#   'lowercaseId': None,
#   'symbol': 'AXL/USDT',
#   'base': 'AXL',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'AXL',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-AXL',
#    'korean_name': '엑셀라',
#    'english_name': 'Axelar'},
#   'tierBased': False,
#   'percentage': True},
#  'YGG/USDT': {'id': 'USDT-YGG',
#   'lowercaseId': None,
#   'symbol': 'YGG/USDT',
#   'base': 'YGG',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'YGG',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-YGG',
#    'korean_name': '일드길드게임즈',
#    'english_name': 'Yield Guild Games'},
#   'tierBased': False,
#   'percentage': True},
#  'SCR/BTC': {'id': 'BTC-SCR',
#   'lowercaseId': None,
#   'symbol': 'SCR/BTC',
#   'base': 'SCR',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'SCR',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-SCR',
#    'korean_name': '스크롤',
#    'english_name': 'Scroll'},
#   'tierBased': False,
#   'percentage': True},
#  'JASMY/USDT': {'id': 'USDT-JASMY',
#   'lowercaseId': None,
#   'symbol': 'JASMY/USDT',
#   'base': 'JASMY',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'JASMY',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-JASMY',
#    'korean_name': '재스미코인',
#    'english_name': 'JasmyCoin'},
#   'tierBased': False,
#   'percentage': True},
#  'WLD/BTC': {'id': 'BTC-WLD',
#   'lowercaseId': None,
#   'symbol': 'WLD/BTC',
#   'base': 'WLD',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'WLD',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-WLD',
#    'korean_name': '월드코인',
#    'english_name': 'Worldcoin'},
#   'tierBased': False,
#   'percentage': True},
#  'VANA/BTC': {'id': 'BTC-VANA',
#   'lowercaseId': None,
#   'symbol': 'VANA/BTC',
#   'base': 'VANA',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'VANA',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-VANA', 'korean_name': '바나', 'english_name': 'Vana'},
#   'tierBased': False,
#   'percentage': True},
#  'LWA/BTC': {'id': 'BTC-LWA',
#   'lowercaseId': None,
#   'symbol': 'LWA/BTC',
#   'base': 'LWA',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'LWA',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-LWA',
#    'korean_name': '루미웨이브',
#    'english_name': 'LumiWave'},
#   'tierBased': False,
#   'percentage': True},
#  'DGB/BTC': {'id': 'BTC-DGB',
#   'lowercaseId': None,
#   'symbol': 'DGB/BTC',
#   'base': 'DGB',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'DGB',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-DGB',
#    'korean_name': '디지바이트',
#    'english_name': 'DigiByte'},
#   'tierBased': False,
#   'percentage': True},
#  'BONK/USDT': {'id': 'USDT-BONK',
#   'lowercaseId': None,
#   'symbol': 'BONK/USDT',
#   'base': 'BONK',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'BONK',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-BONK', 'korean_name': '봉크', 'english_name': 'Bonk'},
#   'tierBased': False,
#   'percentage': True},
#  'BCH/BTC': {'id': 'BTC-BCH',
#   'lowercaseId': None,
#   'symbol': 'BCH/BTC',
#   'base': 'BCH',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'BCH',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-BCH',
#    'korean_name': '비트코인캐시',
#    'english_name': 'Bitcoin Cash'},
#   'tierBased': False,
#   'percentage': True},
#  'JASMY/BTC': {'id': 'BTC-JASMY',
#   'lowercaseId': None,
#   'symbol': 'JASMY/BTC',
#   'base': 'JASMY',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'JASMY',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-JASMY',
#    'korean_name': '재스미코인',
#    'english_name': 'JasmyCoin'},
#   'tierBased': False,
#   'percentage': True},
#  'BORA/KRW': {'id': 'KRW-BORA',
#   'lowercaseId': None,
#   'symbol': 'BORA/KRW',
#   'base': 'BORA',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'BORA',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-BORA', 'korean_name': '보라', 'english_name': 'BORA'},
#   'tierBased': False,
#   'percentage': True},
#  'PUNDIX/KRW': {'id': 'KRW-PUNDIX',
#   'lowercaseId': None,
#   'symbol': 'PUNDIX/KRW',
#   'base': 'PUNDIX',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'PUNDIX',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-PUNDIX',
#    'korean_name': '펀디엑스',
#    'english_name': 'Pundi X'},
#   'tierBased': False,
#   'percentage': True},
#  'ORBS/BTC': {'id': 'BTC-ORBS',
#   'lowercaseId': None,
#   'symbol': 'ORBS/BTC',
#   'base': 'ORBS',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'ORBS',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-ORBS', 'korean_name': '오브스', 'english_name': 'Orbs'},
#   'tierBased': False,
#   'percentage': True},
#  'WAL/USDT': {'id': 'USDT-WAL',
#   'lowercaseId': None,
#   'symbol': 'WAL/USDT',
#   'base': 'WAL',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'WAL',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-WAL',
#    'korean_name': '월러스',
#    'english_name': 'Walrus'},
#   'tierBased': False,
#   'percentage': True},
#  'USD1/KRW': {'id': 'KRW-USD1',
#   'lowercaseId': None,
#   'symbol': 'USD1/KRW',
#   'base': 'USD1',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'USD1',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-USD1',
#    'korean_name': '월드리버티파이낸셜유에스디',
#    'english_name': 'World Liberty Financial USD'},
#   'tierBased': False,
#   'percentage': True},
#  'WLFI/USDT': {'id': 'USDT-WLFI',
#   'lowercaseId': None,
#   'symbol': 'WLFI/USDT',
#   'base': 'WLFI',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'WLFI',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-WLFI',
#    'korean_name': '월드리버티파이낸셜',
#    'english_name': 'World Liberty Financial'},
#   'tierBased': False,
#   'percentage': True},
#  'BAT/KRW': {'id': 'KRW-BAT',
#   'lowercaseId': None,
#   'symbol': 'BAT/KRW',
#   'base': 'BAT',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'BAT',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-BAT',
#    'korean_name': '베이직어텐션토큰',
#    'english_name': 'Basic Attention Token'},
#   'tierBased': False,
#   'percentage': True},
#  'NOM/USDT': {'id': 'USDT-NOM',
#   'lowercaseId': None,
#   'symbol': 'NOM/USDT',
#   'base': 'NOM',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'NOM',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-NOM',
#    'korean_name': '노미나',
#    'english_name': 'Nomina'},
#   'tierBased': False,
#   'percentage': True},
#  'HUNT/KRW': {'id': 'KRW-HUNT',
#   'lowercaseId': None,
#   'symbol': 'HUNT/KRW',
#   'base': 'HUNT',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'HUNT',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-HUNT', 'korean_name': '헌트', 'english_name': 'HUNT'},
#   'tierBased': False,
#   'percentage': True},
#  'PENGU/KRW': {'id': 'KRW-PENGU',
#   'lowercaseId': None,
#   'symbol': 'PENGU/KRW',
#   'base': 'PENGU',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'PENGU',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-PENGU',
#    'korean_name': '펏지펭귄',
#    'english_name': 'Pudgy Penguins'},
#   'tierBased': False,
#   'percentage': True},
#  'FIL/KRW': {'id': 'KRW-FIL',
#   'lowercaseId': None,
#   'symbol': 'FIL/KRW',
#   'base': 'FIL',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'FIL',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-FIL',
#    'korean_name': '파일코인',
#    'english_name': 'Filecoin'},
#   'tierBased': False,
#   'percentage': True},
#  'ANIME/BTC': {'id': 'BTC-ANIME',
#   'lowercaseId': None,
#   'symbol': 'ANIME/BTC',
#   'base': 'ANIME',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'ANIME',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-ANIME',
#    'korean_name': '애니메코인',
#    'english_name': 'Animecoin'},
#   'tierBased': False,
#   'percentage': True},
#  'ORCA/BTC': {'id': 'BTC-ORCA',
#   'lowercaseId': None,
#   'symbol': 'ORCA/BTC',
#   'base': 'ORCA',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'ORCA',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-ORCA', 'korean_name': '오르카', 'english_name': 'Orca'},
#   'tierBased': False,
#   'percentage': True},
#  'BEAM/KRW': {'id': 'KRW-BEAM',
#   'lowercaseId': None,
#   'symbol': 'BEAM/KRW',
#   'base': 'BEAM',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'BEAM',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-BEAM', 'korean_name': '빔', 'english_name': 'Beam'},
#   'tierBased': False,
#   'percentage': True},
#  'SOON/BTC': {'id': 'BTC-SOON',
#   'lowercaseId': None,
#   'symbol': 'SOON/BTC',
#   'base': 'SOON',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'SOON',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-SOON', 'korean_name': '쑨', 'english_name': 'SOON'},
#   'tierBased': False,
#   'percentage': True},
#  'LRC/BTC': {'id': 'BTC-LRC',
#   'lowercaseId': None,
#   'symbol': 'LRC/BTC',
#   'base': 'LRC',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'LRC',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-LRC',
#    'korean_name': '루프링',
#    'english_name': 'Loopring'},
#   'tierBased': False,
#   'percentage': True},
#  'DOOD/KRW': {'id': 'KRW-DOOD',
#   'lowercaseId': None,
#   'symbol': 'DOOD/KRW',
#   'base': 'DOOD',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'DOOD',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-DOOD',
#    'korean_name': '두들즈',
#    'english_name': 'Doodles'},
#   'tierBased': False,
#   'percentage': True},
#  'TOKAMAK/BTC': {'id': 'BTC-TOKAMAK',
#   'lowercaseId': None,
#   'symbol': 'TOKAMAK/BTC',
#   'base': 'TOKAMAK',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'TOKAMAK',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-TOKAMAK',
#    'korean_name': '토카막네트워크',
#    'english_name': 'Tokamak Network'},
#   'tierBased': False,
#   'percentage': True},
#  'SOPH/BTC': {'id': 'BTC-SOPH',
#   'lowercaseId': None,
#   'symbol': 'SOPH/BTC',
#   'base': 'SOPH',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'SOPH',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-SOPH',
#    'korean_name': '소폰',
#    'english_name': 'Sophon'},
#   'tierBased': False,
#   'percentage': True},
#  'STRAX/BTC': {'id': 'BTC-STRAX',
#   'lowercaseId': None,
#   'symbol': 'STRAX/BTC',
#   'base': 'STRAX',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'STRAX',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-STRAX',
#    'korean_name': '스트라티스',
#    'english_name': 'Stratis'},
#   'tierBased': False,
#   'percentage': True},
#  'WAVES/KRW': {'id': 'KRW-WAVES',
#   'lowercaseId': None,
#   'symbol': 'WAVES/KRW',
#   'base': 'WAVES',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'WAVES',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-WAVES',
#    'korean_name': '웨이브',
#    'english_name': 'Waves'},
#   'tierBased': False,
#   'percentage': True},
#  'USDC/KRW': {'id': 'KRW-USDC',
#   'lowercaseId': None,
#   'symbol': 'USDC/KRW',
#   'base': 'USDC',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'USDC',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
# ...
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-RSR',
#    'korean_name': '리저브라이트',
#    'english_name': 'Reserve Rights'},
#   'tierBased': False,
#   'percentage': True},
#  'DEEP/KRW': {'id': 'KRW-DEEP',
#   'lowercaseId': None,
#   'symbol': 'DEEP/KRW',
#   'base': 'DEEP',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'DEEP',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-DEEP',
#    'korean_name': '딥북',
#    'english_name': 'DeepBook'},
#   'tierBased': False,
#   'percentage': True},
#  'ARB/BTC': {'id': 'BTC-ARB',
#   'lowercaseId': None,
#   'symbol': 'ARB/BTC',
#   'base': 'ARB',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'ARB',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-ARB',
#    'korean_name': '아비트럼',
#    'english_name': 'Arbitrum'},
#   'tierBased': False,
#   'percentage': True},
#  'AERGO/BTC': {'id': 'BTC-AERGO',
#   'lowercaseId': None,
#   'symbol': 'AERGO/BTC',
#   'base': 'AERGO',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'AERGO',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-AERGO',
#    'korean_name': '아르고',
#    'english_name': 'Aergo'},
#   'tierBased': False,
#   'percentage': True},
#  'DEEP/USDT': {'id': 'USDT-DEEP',
#   'lowercaseId': None,
#   'symbol': 'DEEP/USDT',
#   'base': 'DEEP',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'DEEP',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-DEEP',
#    'korean_name': '딥북',
#    'english_name': 'DeepBook'},
#   'tierBased': False,
#   'percentage': True},
#  'ARK/BTC': {'id': 'BTC-ARK',
#   'lowercaseId': None,
#   'symbol': 'ARK/BTC',
#   'base': 'ARK',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'ARK',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-ARK', 'korean_name': '아크', 'english_name': 'Ark'},
#   'tierBased': False,
#   'percentage': True},
#  'STRAX/KRW': {'id': 'KRW-STRAX',
#   'lowercaseId': None,
#   'symbol': 'STRAX/KRW',
#   'base': 'STRAX',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'STRAX',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-STRAX',
#    'korean_name': '스트라티스',
#    'english_name': 'Stratis'},
#   'tierBased': False,
#   'percentage': True},
#  'STORJ/BTC': {'id': 'BTC-STORJ',
#   'lowercaseId': None,
#   'symbol': 'STORJ/BTC',
#   'base': 'STORJ',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'STORJ',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-STORJ',
#    'korean_name': '스토리지',
#    'english_name': 'Storj'},
#   'tierBased': False,
#   'percentage': True},
#  'BLAST/BTC': {'id': 'BTC-BLAST',
#   'lowercaseId': None,
#   'symbol': 'BLAST/BTC',
#   'base': 'BLAST',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'BLAST',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-BLAST',
#    'korean_name': '블라스트',
#    'english_name': 'Blast'},
#   'tierBased': False,
#   'percentage': True},
#  'BRETT/USDT': {'id': 'USDT-BRETT',
#   'lowercaseId': None,
#   'symbol': 'BRETT/USDT',
#   'base': 'BRETT',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'BRETT',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-BRETT',
#    'korean_name': '브렛',
#    'english_name': 'Brett'},
#   'tierBased': False,
#   'percentage': True},
#  'META/BTC': {'id': 'BTC-META',
#   'lowercaseId': None,
#   'symbol': 'META/BTC',
#   'base': 'META',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'META',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-META',
#    'korean_name': '메타디움',
#    'english_name': 'Metadium'},
#   'tierBased': False,
#   'percentage': True},
#  'SYRUP/USDT': {'id': 'USDT-SYRUP',
#   'lowercaseId': None,
#   'symbol': 'SYRUP/USDT',
#   'base': 'SYRUP',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'SYRUP',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-SYRUP',
#    'korean_name': '메이플파이낸스',
#    'english_name': 'Maple Finance'},
#   'tierBased': False,
#   'percentage': True},
#  'DENT/BTC': {'id': 'BTC-DENT',
#   'lowercaseId': None,
#   'symbol': 'DENT/BTC',
#   'base': 'DENT',
#   'quote': 'BTC',
#   'settle': None,
#   'baseId': 'DENT',
#   'quoteId': 'BTC',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'BTC-DENT', 'korean_name': '덴트', 'english_name': 'Dent'},
#   'tierBased': False,
#   'percentage': True},
#  'ICX/KRW': {'id': 'KRW-ICX',
#   'lowercaseId': None,
#   'symbol': 'ICX/KRW',
#   'base': 'ICX',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'ICX',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-ICX', 'korean_name': '아이콘', 'english_name': 'Icon'},
#   'tierBased': False,
#   'percentage': True},
#  'SOMI/USDT': {'id': 'USDT-SOMI',
#   'lowercaseId': None,
#   'symbol': 'SOMI/USDT',
#   'base': 'SOMI',
#   'quote': 'USDT',
#   'settle': None,
#   'baseId': 'SOMI',
#   'quoteId': 'USDT',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0025,
#   'maker': 0.0025,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'USDT-SOMI',
#    'korean_name': '솜니아',
#    'english_name': 'Somnia'},
#   'tierBased': False,
#   'percentage': True},
#  'POLYX/KRW': {'id': 'KRW-POLYX',
#   'lowercaseId': None,
#   'symbol': 'POLYX/KRW',
#   'base': 'POLYX',
#   'quote': 'KRW',
#   'settle': None,
#   'baseId': 'POLYX',
#   'quoteId': 'KRW',
#   'settleId': None,
#   'type': 'spot',
#   'spot': True,
#   'margin': False,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'index': False,
#   'active': True,
#   'contract': False,
#   'linear': None,
#   'inverse': None,
#   'subType': None,
#   'taker': 0.0005,
#   'maker': 0.0005,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'strike': None,
#   'optionType': None,
#   'precision': {'amount': 1e-08,
#    'price': 1e-08,
#    'cost': None,
#    'base': None,
#    'quote': None},
#   'limits': {'leverage': {'min': None, 'max': None},
#    'amount': {'min': None, 'max': None},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': None, 'max': None}},
#   'marginModes': {'cross': None, 'isolated': None},
#   'created': None,
#   'info': {'market': 'KRW-POLYX',
#    'korean_name': '폴리매쉬',
#    'english_name': 'Polymesh'},
#   'tierBased': False,
#   'percentage': True}}

# %%
# 저장 폴더
Path("data").mkdir(exist_ok=True, parents=True)

# %%
def append_parquet(path: str, df_new: pd.DataFrame):
    df_new = df_new.drop_duplicates(subset=["ts"]).sort_values("ts")
    if Path(path).exists():
        old = pd.read_parquet(path)
        df = pd.concat([old, df_new], ignore_index=True)
        df = df.drop_duplicates(subset=["ts"]).sort_values("ts")
    else:
        df = df_new
    df.to_parquet(path, index=False)

# %%
def main():
    since = ex.parse8601(START_ISO)
    end_ms = ex.milliseconds() - END_BUFFER_SEC * 1000

    empty_streak = 0
    batch_count  = 0
    buffer = []  # 메모리 절약하려면 주기적으로 파일에 flush

    while since < end_ms:
        try:
            ohlcv = ex.fetch_ohlcv(SYMBOL, timeframe=TIMEFRAME, since=since, limit=CHUNK_LIMIT)

            if ohlcv:
                df = pd.DataFrame(ohlcv, columns=["ts","open","high","low","close","volume"])
                df["time"] = pd.to_datetime(df["ts"], unit="ms", utc=True).dt.tz_convert("Asia/Seoul")
                buffer.append(df)

                last_ts = int(df["ts"].iloc[-1])
                since   = last_ts + 1              # 정확히 이어붙이기
                empty_streak = 0
                batch_count += 1
                
                # 주기적으로 저장(메모리 절약 & 중간 보존)
                if batch_count % 20 == 0:          # 20 청크마다 저장
                    append_parquet(SAVE_PATH, pd.concat(buffer, ignore_index=True))
                    print(f"[flush] up to {df['time'].iloc[-1]} → {SAVE_PATH}")
                    buffer = []

                print(f"{df['time'].iloc[0]} ~ {df['time'].iloc[-1]} (n={len(df)})")

            else:
                # 비어 있으면 ‘끝’으로 보지 말고 커서를 한 덩어리 건너뛰어 진행
                empty_streak += 1
                if empty_streak > MAX_EMPTY_CHUNKS:
                    print(f"연속 빈 응답 {empty_streak}회 → 종료(실제 끝으로 판단)")
                    break

                jump = TIMEFRAME_MS * CHUNK_LIMIT
                since = min(since + jump, end_ms)
                print(f"[empty #{empty_streak}] jump cursor → {pd.to_datetime(since, unit='ms', utc=True).tz_convert('Asia/Seoul')}")
                time.sleep(ex.rateLimit / 1000)

        except Exception as e:
            print("오류:", e)
            time.sleep(3)  # 지수 백오프로 바꿔도 좋음

    # 남은 버퍼 최종 저장
    if buffer:
        append_parquet(SAVE_PATH, pd.concat(buffer, ignore_index=True))
        print(f"[final flush] → {SAVE_PATH}")

    print("✅ 수집 종료")

# %%
if __name__ == "__main__":
    main()
# Out:
# 2020-01-01 09:00:00+09:00 ~ 2020-07-18 09:00:00+09:00 (n=200)
# 2020-07-19 09:00:00+09:00 ~ 2021-02-03 09:00:00+09:00 (n=200)
# 2021-02-04 09:00:00+09:00 ~ 2021-08-22 09:00:00+09:00 (n=200)
# 2021-08-23 09:00:00+09:00 ~ 2022-03-10 09:00:00+09:00 (n=200)
# 2022-03-11 09:00:00+09:00 ~ 2022-09-26 09:00:00+09:00 (n=200)
# 2022-09-27 09:00:00+09:00 ~ 2023-04-14 09:00:00+09:00 (n=200)
# 2023-04-15 09:00:00+09:00 ~ 2023-10-31 09:00:00+09:00 (n=200)
# 2023-11-01 09:00:00+09:00 ~ 2024-05-18 09:00:00+09:00 (n=200)
# 2024-05-19 09:00:00+09:00 ~ 2024-12-04 09:00:00+09:00 (n=200)
# 2024-12-05 09:00:00+09:00 ~ 2025-06-22 09:00:00+09:00 (n=200)
# 2025-06-23 09:00:00+09:00 ~ 2025-11-13 09:00:00+09:00 (n=144)
# [empty #1] jump cursor → 2025-11-13 10:46:06+09:00
# [final flush] → data/ohlcv_full_ETHKRW_1d.parquet
# ✅ 수집 종료
